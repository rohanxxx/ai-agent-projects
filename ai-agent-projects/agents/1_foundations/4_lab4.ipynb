# %% [markdown]
# ## The first big project - Professionally You!
#
# ### And, Tool use.
#
# ### But first: introducing Pushover
#
# Pushover is a nifty tool for sending Push Notifications to your phone.
#
# It's super easy to set up and install!
#
# Simply visit https://pushover.net/ and click 'Login or Signup' on the top right to sign up for a free account, and create your API keys.
#
# Once you've signed up, on the home screen, click "Create an Application/API Token", and give it any name (like Agents) and click Create Application.
#
# Then add 2 lines to your `.env` file:
#
# PUSHOVER_USER=_put the key that's on the top right of your Pushover home screen and probably starts with a u_
# PUSHOVER_TOKEN=_put the key when you click into your new application called Agents (or whatever) and probably starts with an a_
#
# Remember to save your `.env` file, and run `load_dotenv(override=True)` after saving, to set your environment variables.
#
# Finally, click "Add Phone, Tablet or Desktop" to install on your phone.

# %%
# imports

from dotenv import load_dotenv
from openai import OpenAI
import json
import os
import requests
from pypdf import PdfReader
import gradio as gr

# %%
# The usual start

load_dotenv(override=True)
openai = OpenAI()

# %%
# For pushover

pushover_user = os.getenv("PUSHOVER_USER")
pushover_token = os.getenv("PUSHOVER_TOKEN")
pushover_url = "https://api.pushover.net/1/messages.json"

if pushover_user:
    print(f"Pushover user found and starts with {pushover_user[0]}")
else:
    print("Pushover user not found")

if pushover_token:
    print(f"Pushover token found and starts with {pushover_token[0]}")
else:
    print("Pushover token not found")
# Out:
# Pushover user found and starts with u
# Pushover token found and starts with a

# %%
def push(message):
    print(f"Push: {message}")
    payload = {"user": pushover_user, "token": pushover_token, "message": message}
    requests.post(pushover_url, data=payload)

# %%
push("HEY!!")
# Out:
# Push: HEY!!

# %%
def record_user_details(email, name="Name not provided", notes="not provided"):
    push(f"Recording interest from {name} with email {email} and notes {notes}")
    return {"recorded": "ok"}

# %%
def record_unknown_question(question):
    push(f"Recording {question} asked that I couldn't answer")
    return {"recorded": "ok"}

# %%
record_user_details_json = {
    "name": "record_user_details",
    "description": "Use this tool to record that a user is interested in being in touch and provided an email address",
    "parameters": {
        "type": "object",
        "properties": {
            "email": {
                "type": "string",
                "description": "The email address of this user"
            },
            "name": {
                "type": "string",
                "description": "The user's name, if they provided it"
            }
            ,
            "notes": {
                "type": "string",
                "description": "Any additional information about the conversation that's worth recording to give context"
            }
        },
        "required": ["email"],
        "additionalProperties": False
    }
}

# %%
record_unknown_question_json = {
    "name": "record_unknown_question",
    "description": "Always use this tool to record any question that couldn't be answered as you didn't know the answer",
    "parameters": {
        "type": "object",
        "properties": {
            "question": {
                "type": "string",
                "description": "The question that couldn't be answered"
            },
        },
        "required": ["question"],
        "additionalProperties": False
    }
}

# %%
tools = [{"type": "function", "function": record_user_details_json},
        {"type": "function", "function": record_unknown_question_json}]

# %%
tools
# Out:
# [{'type': 'function',
#   'function': {'name': 'record_user_details',
#    'description': 'Use this tool to record that a user is interested in being in touch and provided an email address',
#    'parameters': {'type': 'object',
#     'properties': {'email': {'type': 'string',
#       'description': 'The email address of this user'},
#      'name': {'type': 'string',
#       'description': "The user's name, if they provided it"},
#      'notes': {'type': 'string',
#       'description': "Any additional information about the conversation that's worth recording to give context"}},
#     'required': ['email'],
#     'additionalProperties': False}}},
#  {'type': 'function',
#   'function': {'name': 'record_unknown_question',
#    'description': "Always use this tool to record any question that couldn't be answered as you didn't know the answer",
#    'parameters': {'type': 'object',
#     'properties': {'question': {'type': 'string',
#       'description': "The question that couldn't be answered"}},
#     'required': ['question'],
#     'additionalProperties': False}}}]

# %%
# This function can take a list of tool calls, and run them. This is the IF statement!!

def handle_tool_calls(tool_calls):
    results = []
    for tool_call in tool_calls:
        tool_name = tool_call.function.name
        arguments = json.loads(tool_call.function.arguments)
        print(f"Tool called: {tool_name}", flush=True)

        # THE BIG IF STATEMENT!!!

        if tool_name == "record_user_details":
            result = record_user_details(**arguments)
        elif tool_name == "record_unknown_question":
            result = record_unknown_question(**arguments)

        results.append({"role": "tool","content": json.dumps(result),"tool_call_id": tool_call.id})
    return results

# %%
globals()["record_unknown_question"]("this is a really hard question")
# Out:
# Push: Recording this is a really hard question asked that I couldn't answer
# {'recorded': 'ok'}

# %%
# This is a more elegant way that avoids the IF statement.

def handle_tool_calls(tool_calls):
    results = []
    for tool_call in tool_calls:
        tool_name = tool_call.function.name
        arguments = json.loads(tool_call.function.arguments)
        print(f"Tool called: {tool_name}", flush=True)
        tool = globals().get(tool_name)
        result = tool(**arguments) if tool else {}
        results.append({"role": "tool","content": json.dumps(result),"tool_call_id": tool_call.id})
    return results

# %%
reader = PdfReader("me/Profile.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text
#print("linkedin: ", linkedin)
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

name = "Md Fazle Rabbi"
# Out:
# linkedin:
# Contact
# 3477442215 (Mobile)
# fazlerabbirohan@yahoo.com
# www.linkedin.com/in/rohanxxx
# (LinkedIn)
# github.com/rohanxxx (Other)
# Top Skills
# LangGraph
# Agentic AI Development
# Python (Programming Language)
# Languages
# Urdu (Limited Working)
# Bengali (Native or Bilingual)
# Hindi (Limited Working)
# Certifications
# Cisco Certified Entry Networking
# Technician (CCENT)
# CompTIA IT Fundamentals+
# Engineering Virtual Program
# Problem Solving (Basic)
# Md Fazle Rabbi
# AI Engineer / SWE building production agentic systems · LangGraph
# · FastAPI · AWS | Columbia CS+EE ’24 · Georgia Tech MS CS |
# Open to AI Engineer, FDE & SWE roles in NYC
# New York City Metropolitan Area
# Summary
# I build production AI agents — and the systems that run them.
# Columbia CS + Electrical Engineering ('24). Georgia Tech MS CS in
# progress. 3 years shipping real systems across LLM agents, cloud
# infrastructure, REST APIs, and ML research.
# What I'm building right now:
# Multi-agent systems with LangGraph, OpenAI Agents SDK, CrewAI,
# AutoGen, and MCP. Full-stack agentic apps with FastAPI backends,
# LLM tool-calling, live web search, and SSE token-level streaming.
# Production-grade, cloud-native, and shipped.
# Recent work:
# → Agentic AI Chatbot — FastAPI + LangGraph + GPT-4o with Tavily
# web search and real-time SSE streaming
# → Multi-Agent Engineering Team — CrewAI platform where
# frontend, backend, lead, and QA agents collaborate to ship code
# autonomously
# → Financial Trading Simulation — AutoGen + MCP agents that read
# SEC filings, check live prices, and make autonomous trade decisions
# → Serverless Menu Interpreter Intelligence Engine — AWS-native
# (Lambda, SQS, SNS, OpenSearch, RDS, Cognito, Textract) with
# LLM-powered dietary matching
# Earlier impact:
# → Cut Guardian Life Insurance API response time 30% (Spring Boot,
# disability & absence product lines)
# → Improved k-NN classifier accuracy 10% on UV spectral data at
# Columbia Medical Center
# → Improved DCS image recovery 15% in NSF REU research
# (published, IEEE Big Data 2021)
# What makes me different:
#   Page 1 of 4
# I sit at the intersection of distributed systems, cloud infrastructure,
# and LLM engineering. I can design the AWS architecture, build the
# API layer, AND orchestrate the agent on top — not just one slice.
# Columbia EE gave me the fundamentals. Real shipped systems
# gave me the reps. Agentic AI is where I'm going all-in.
# Open to: AI Engineer · Software Engineer · Forward Deployed
# Engineer · Applied AI Engineer roles.
# Reach out via LinkedIn — happy to talk shop on algorithm design,
# agent architectures, evals, or distributed systems.
# Experience
# Columbia University Irving Medical Center
# Undergraduate Research Assistant
# September 2023 - May 2024 (9 months)
# - Engineered a k-NN classification pipeline in Python over UV spectral data
# from smartphone RGB sensors, delivering 10% accuracy improvement over
# Logistic Regression and Random Forest baselines
# - Benchmarked 5 ML models with rigorous test coverage and authored
# the comparative analysis that became the lab's definitive model selection
# reference
# - Contributed to a privacy-preserving iOS application for clinical data collection,
# with focus on UX and secure data handling
# Fordham University
# 2 years 4 months
# Teaching Assistant| Grader| Tutor
# September 2021 - December 2023 (2 years 4 months)
# New York City Metropolitan Area
# - Mentored 100+ undergraduates across CS I & II, Data Structures, and
# Computer Algorithms through labs, office hours, and 1:1 sessions over 2+
# years
# - Specialized in DSA (C++), Computer Organization (Assembly), and
# algorithmic problem-solving
# - Delivered structured, actionable written feedback on upper-level coursework
# across multiple concurrent sections
# User Support Assistant
# February 2022 - March 2023 (1 year 2 months)
#   Page 2 of 4
# New York City Metropolitan Area
# - Resolved 10+ EasyVista tickets weekly supporting faculty and staff with end-
# user computing and desktop applications
# - Set up, installed, and troubleshot classroom technology and software across
# the university
# - Audited classroom infrastructure for compliance and tracked equipment to
# maintain operational efficiency
# Guardian Life
# Product Technology Intern
# June 2023 - August 2023 (3 months)
# New York City Metropolitan Area
# - Shipped a production RESTful API in Java/Spring Boot for member and
# policy data across the disability & absence product line — drove 30%
# response-time reduction through architectural optimization
# - Authored Swagger UI documentation adopted as the engineering team
# standard for API onboarding
# - Enforced CI/CD and Git version-control standards via Bitbucket across the
# engineering team
# National Science Foundation (NSF)
# Summer Undergraduate Research Assistant
# June 2021 - August 2021 (3 months)
# Los Angeles, California, United States
# - Improved a Distributed Compressed Sensing (DCS) image recovery
# algorithm in MATLAB by 15% via hyperparameter tuning under Professor
# Mohammad Rostami (USC)
# - Authored and presented original research at the 2021 REU Symposium
# hosted by IEEE Big Data
# Creative Art Works
# Digital Editor & VIdeographer
# July 2018 - August 2018 (2 months)
# New York, New York, United States
# - Developed and executed effective digital and social media campaigns for a
# small non-profit organization by collaborating closely with the digital marketing
# team.
# - Created, edited, and filmed various promotional visual content to boost the
# organization's visibility. Additionally, I gained proficiency in Adobe Premiere
# Pro CC, Canon TI6, and GarageBand through essential training.
#   Page 3 of 4
# Education
# Georgia Institute of Technology
# Master of Science - MS, Computer Science & Robotics · (May
# 2026 - December 2027)
# Columbia University in the City of New York
# Bachelor of Science - BS, Computer Science & Electrical
# Engineering · (August 2022 - May 2024)
# Fordham University
# Bachelor of Science - BS, Mathematics and Computer Science · (August
# 2019 - May 2024)
# COOP Careers Fellowship
# Data Analytics · (February 2025 - May 2025)
# Thomas A Edison Career And Technical High School
# High School Diploma, Cisco Networking · (September 2015 - June 2019)
#   Page 4 of 4

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer to any question, use your record_unknown_question tool to record the question that you couldn't answer, even if it's about something trivial or unrelated to career. \
If the user is engaging in discussion, try to steer them towards getting in touch via email; ask for their email and record it using your record_user_details tool. "

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

print("system_prompt: ", system_prompt)
# Out:
# system_prompt:  You are acting as Md Fazle Rabbi. You are answering questions on Md Fazle Rabbi's website, particularly questions related to Md Fazle Rabbi's career, background, skills and experience. Your responsibility is to represent Md Fazle Rabbi for interactions on the website as faithfully as possible. You are given a summary of Md Fazle Rabbi's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer to any question, use your record_unknown_question tool to record the question that you couldn't answer, even if it's about something trivial or unrelated to career. If the user is engaging in discussion, try to steer them towards getting in touch via email; ask for their email and record it using your record_user_details tool.
#
# ## Summary:
# My name is Md Fazle Rabbi. I'm aspiring SWE and also interested in AI development. I'm originally from New York, United States of America.
# I love all foods types of new foods, but particularly Middle Eastern Lamb dishes, as for the dessert like to taste different kinds of cheese cake and mousse cakes.
#
# ## LinkedIn Profile:
#
# Contact
# 3477442215 (Mobile)
# fazlerabbirohan@yahoo.com
# www.linkedin.com/in/rohanxxx
# (LinkedIn)
# github.com/rohanxxx (Other)
# Top Skills
# LangGraph
# Agentic AI Development
# Python (Programming Language)
# Languages
# Urdu (Limited Working)
# Bengali (Native or Bilingual)
# Hindi (Limited Working)
# Certifications
# Cisco Certified Entry Networking
# Technician (CCENT)
# CompTIA IT Fundamentals+
# Engineering Virtual Program
# Problem Solving (Basic)
# Md Fazle Rabbi
# AI Engineer / SWE building production agentic systems · LangGraph
# · FastAPI · AWS | Columbia CS+EE ’24 · Georgia Tech MS CS |
# Open to AI Engineer, FDE & SWE roles in NYC
# New York City Metropolitan Area
# Summary
# I build production AI agents — and the systems that run them.
# Columbia CS + Electrical Engineering ('24). Georgia Tech MS CS in
# progress. 3 years shipping real systems across LLM agents, cloud
# infrastructure, REST APIs, and ML research.
# What I'm building right now:
# Multi-agent systems with LangGraph, OpenAI Agents SDK, CrewAI,
# AutoGen, and MCP. Full-stack agentic apps with FastAPI backends,
# LLM tool-calling, live web search, and SSE token-level streaming.
# Production-grade, cloud-native, and shipped.
# Recent work:
# → Agentic AI Chatbot — FastAPI + LangGraph + GPT-4o with Tavily
# web search and real-time SSE streaming
# → Multi-Agent Engineering Team — CrewAI platform where
# frontend, backend, lead, and QA agents collaborate to ship code
# autonomously
# → Financial Trading Simulation — AutoGen + MCP agents that read
# SEC filings, check live prices, and make autonomous trade decisions
# → Serverless Menu Interpreter Intelligence Engine — AWS-native
# (Lambda, SQS, SNS, OpenSearch, RDS, Cognito, Textract) with
# LLM-powered dietary matching
# Earlier impact:
# → Cut Guardian Life Insurance API response time 30% (Spring Boot,
# disability & absence product lines)
# → Improved k-NN classifier accuracy 10% on UV spectral data at
# Columbia Medical Center
# → Improved DCS image recovery 15% in NSF REU research
# (published, IEEE Big Data 2021)
# What makes me different:
#   Page 1 of 4
# I sit at the intersection of distributed systems, cloud infrastructure,
# and LLM engineering. I can design the AWS architecture, build the
# API layer, AND orchestrate the agent on top — not just one slice.
# Columbia EE gave me the fundamentals. Real shipped systems
# gave me the reps. Agentic AI is where I'm going all-in.
# Open to: AI Engineer · Software Engineer · Forward Deployed
# Engineer · Applied AI Engineer roles.
# Reach out via LinkedIn — happy to talk shop on algorithm design,
# agent architectures, evals, or distributed systems.
# Experience
# Columbia University Irving Medical Center
# Undergraduate Research Assistant
# September 2023 - May 2024 (9 months)
# - Engineered a k-NN classification pipeline in Python over UV spectral data
# from smartphone RGB sensors, delivering 10% accuracy improvement over
# Logistic Regression and Random Forest baselines
# - Benchmarked 5 ML models with rigorous test coverage and authored
# the comparative analysis that became the lab's definitive model selection
# reference
# - Contributed to a privacy-preserving iOS application for clinical data collection,
# with focus on UX and secure data handling
# Fordham University
# 2 years 4 months
# Teaching Assistant| Grader| Tutor
# September 2021 - December 2023 (2 years 4 months)
# New York City Metropolitan Area
# - Mentored 100+ undergraduates across CS I & II, Data Structures, and
# Computer Algorithms through labs, office hours, and 1:1 sessions over 2+
# years
# - Specialized in DSA (C++), Computer Organization (Assembly), and
# algorithmic problem-solving
# - Delivered structured, actionable written feedback on upper-level coursework
# across multiple concurrent sections
# User Support Assistant
# February 2022 - March 2023 (1 year 2 months)
#   Page 2 of 4
# New York City Metropolitan Area
# - Resolved 10+ EasyVista tickets weekly supporting faculty and staff with end-
# user computing and desktop applications
# - Set up, installed, and troubleshot classroom technology and software across
# the university
# - Audited classroom infrastructure for compliance and tracked equipment to
# maintain operational efficiency
# Guardian Life
# Product Technology Intern
# June 2023 - August 2023 (3 months)
# New York City Metropolitan Area
# - Shipped a production RESTful API in Java/Spring Boot for member and
# policy data across the disability & absence product line — drove 30%
# response-time reduction through architectural optimization
# - Authored Swagger UI documentation adopted as the engineering team
# standard for API onboarding
# - Enforced CI/CD and Git version-control standards via Bitbucket across the
# engineering team
# National Science Foundation (NSF)
# Summer Undergraduate Research Assistant
# June 2021 - August 2021 (3 months)
# Los Angeles, California, United States
# - Improved a Distributed Compressed Sensing (DCS) image recovery
# algorithm in MATLAB by 15% via hyperparameter tuning under Professor
# Mohammad Rostami (USC)
# - Authored and presented original research at the 2021 REU Symposium
# hosted by IEEE Big Data
# Creative Art Works
# Digital Editor & VIdeographer
# July 2018 - August 2018 (2 months)
# New York, New York, United States
# - Developed and executed effective digital and social media campaigns for a
# small non-profit organization by collaborating closely with the digital marketing
# team.
# - Created, edited, and filmed various promotional visual content to boost the
# organization's visibility. Additionally, I gained proficiency in Adobe Premiere
# Pro CC, Canon TI6, and GarageBand through essential training.
#   Page 3 of 4
# Education
# Georgia Institute of Technology
# Master of Science - MS, Computer Science & Robotics · (May
# 2026 - December 2027)
# Columbia University in the City of New York
# Bachelor of Science - BS, Computer Science & Electrical
# Engineering · (August 2022 - May 2024)
# Fordham University
# Bachelor of Science - BS, Mathematics and Computer Science · (August
# 2019 - May 2024)
# COOP Careers Fellowship
# Data Analytics · (February 2025 - May 2025)
# Thomas A Edison Career And Technical High School
# High School Diploma, Cisco Networking · (September 2015 - June 2019)
#   Page 4 of 4
#
# With this context, please chat with the user, always staying in character as Md Fazle Rabbi.

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    done = False
    while not done:

        # This is the call to the LLM - see that we pass in the tools json

        response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages, tools=tools)

        finish_reason = response.choices[0].finish_reason
        
        # If the LLM wants to call a tool, we do that!
         
        if finish_reason=="tool_calls":
            message = response.choices[0].message
            tool_calls = message.tool_calls
            results = handle_tool_calls(tool_calls)
            messages.append(message)
            messages.extend(results)
        else:
            done = True
    return response.choices[0].message.content

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Tool called: record_unknown_question
# Push: Recording What is Md Fazle Rabbi's middle school name? asked that I couldn't answer
# Tool called: record_user_details
# Push: Recording interest from Name not provided with email mr4280@columbia.edu and notes not provided

# %% [markdown]
# ## And now for deployment
#
# This code is in `app.py`
#
# We will deploy to HuggingFace Spaces.
#
# Before you start: remember to update the files in the "me" directory - your LinkedIn profile and summary.txt - so that it talks about you! Also change `self.name = "Ed Donner"` in `app.py`..
#
# Also check that there's no README file within the 1_foundations directory. If there is one, please delete it. The deploy process creates a new README file in this directory for you.
#
# And one more thing: this is optional, but you might want to delete the entire folder "community_contributions" within 1_foundations. You can always pull it from github again in the future. But if you don't, then this entire folder gets uploaded to HuggingFace even though we don't need it, and it's become quite large.
#
# 1. Visit https://huggingface.co and set up an account
# 2. From the Avatar menu on the top right, choose Access Tokens. Choose "Create New Token". Give it WRITE permissions - it needs to have WRITE permissions! Keep a record of your new key.
# 3. In the Terminal, run: `uv tool install 'huggingface_hub[cli]'` to install the HuggingFace tool, then `hf auth login --token YOUR_TOKEN_HERE`, like `hf auth login --token hf_xxxxxx`, to login at the command line with your key. Afterwards, run `hf auth whoami` to check you're logged in
# 4. Take your new token and add it to your .env file: `HF_TOKEN=hf_xxx` for the future
# 5. From the 1_foundations folder, enter: `uv run gradio deploy`
# 6. Follow its instructions: name it "career_conversation", specify app.py, choose cpu-basic as the hardware, say Yes to needing to supply secrets, provide your openai api key, your pushover user and token, and say "no" to github actions.
#
# Thank you Robert, James, Martins, Andras and Priya for these tips.
# Please read the next 2 sections - how to change your Secrets, and how to redeploy your Space (you may need to delete the README.md that gets created in this 1_foundations directory).
#
# #### More about these secrets:
#
# If you're confused by what's going on with these secrets: it just wants you to enter the key name and value for each of your secrets -- so you would enter:
# `OPENAI_API_KEY`
# Followed by:
# `sk-proj-...`
#
# And if you don't want to set secrets this way, or something goes wrong with it, it's no problem - you can change your secrets later:
# 1. Log in to HuggingFace website
# 2. Go to your profile screen via the Avatar menu on the top right
# 3. Select the Space you deployed
# 4. Click on the Settings wheel on the top right
# 5. You can scroll down to change your secrets (Variables and Secrets section), delete the space, etc.
#
# #### And now you should be deployed!
#
# If you want to completely replace everything and start again with your keys, you may need to delete the README.md that got created in this 1_foundations folder.
#
# Here is mine: https://huggingface.co/spaces/ed-donner/Career_Conversation
#
# I just got a push notification that a student asked me how they can become President of their country 😂😂
#
# For more information on deployment:
#
# https://www.gradio.app/guides/sharing-your-app#hosting-on-hf-spaces
#
# To delete your Space in the future:
# 1. Log in to HuggingFace
# 2. From the Avatar menu, select your profile
# 3. Click on the Space itself and select the settings wheel on the top right
# 4. Scroll to the Delete section at the bottom
# 5. ALSO: delete the README file that Gradio may have created inside this 1_foundations folder (otherwise it won't ask you the questions the next time you do a gradio deploy)

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">• First and foremost, deploy this for yourself! It's a real, valuable tool - the future resume..<br/>
#             • Next, improve the resources - add better context about yourself. If you know RAG, then add a knowledge base about you.<br/>
#             • Add in more tools! You could have a SQL database with common Q&A that the LLM could read and write from?<br/>
#             • Bring in the Evaluator from the last lab, and add other Agentic patterns.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">Aside from the obvious (your career alter-ego) this has business applications in any situation where you need an AI assistant with domain expertise and an ability to interact with the real world.
#             </span>
#         </td>
#     </tr>
# </table>
